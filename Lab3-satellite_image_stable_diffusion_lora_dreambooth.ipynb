# %% [markdown]
# # Using Stable Diffusion to generate dataset examples
# We explore using a fine-tuned version of Stable Diffusion to generate examples of satellite images. Tested using SageMaker Studio, PyTorch 2.0 Python 3.10 GPU kernel on g4dn.xlarge.
#
# In this tutorial, we go through using LoRA and Dreambooth to fine-tune Stable Diffusion, a text-to-image generation model, to generate additional satellite images to augment your dataset.

# %%
# !nvidia-smi
# Out:
# Fri Jun 23 04:12:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   26C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers accelerate>=0.16.0 ftfy tensorboard Jinja2 huggingface_hub wandb kaggle git+https://github.com/huggingface/diffusers
# Out:
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-2qt2h00v
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sparkmagic 0.20.5 requires nest-asyncio==1.5.5, but you have nest-asyncio 1.5.6 which is incompatible.
# sparkmagic 0.20.5 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.0.1 which is incompatible.
# sphinx 7.0.0 requires docutils<0.20,>=0.18.1, but you have docutils 0.16 which is incompatible.

# %% [markdown]
# ## Setup Kaggle
# Follow the instructions [here](https://github.com/Kaggle/kaggle-api#api-credentials) to get your Kaggle credentials.
# Open the JSON file on your computer and update the username and key with your values.

# %% [markdown]
# UPDATE WITH YOUR CREDENTIALS

# %%
# %%writefile ./home/ec2-user/.kaggle/kaggle.json
# {"username":"ENTERUSERNAME","key":"ENTERKEY"}

# %%
# !kaggle datasets download apollo2506/eurosat-dataset
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ec2-user/.kaggle/kaggle.json'
# Downloading eurosat-dataset.zip to /home/ec2-user/SageMaker
# 100%|█████████████████████████████████████▉| 2.04G/2.04G [01:32<00:00, 25.5MB/s]
# 100%|██████████████████████████████████████| 2.04G/2.04G [01:32<00:00, 23.7MB/s]

# %% [markdown]
# ### Dataset
# For this tutorial, we will use the EuroSAT dataset, which is a land use classification dataset consisting of Sentinel 2 Satellite images. We will use the `Highway` class as the type of satellite image that we would like to generate. The `Forest` and `Industrial` classes serve as the *class* that we want the model to separate the `Highway` *instance*. Check out the original [Dreambooth paper](https://dreambooth.github.io/) to find out more.

# %% [markdown]
# In these commands -q supresses printing messages, -d switches the directory. This does take a bit of time.

# %%
# !mkdir -p ./studies/Sagemaker_Study/SI/Highway
# !unzip -q eurosat-dataset.zip "EuroSAT/Forest/*" -d "./studies/Sagemaker_Study/SI/Highway/Forest"

# %%
# !unzip -q eurosat-dataset.zip "EuroSAT/Industrial/*" -d "./studies/Sagemaker_Study/SI/Highway/Industrial"

# %%
# !unzip -q eurosat-dataset.zip "EuroSAT/Highway/*" -d "./studies/Sagemaker_Study/SI/Highway/Highway"

# %% [markdown]
# ## View Dataset
# Let's view the `Highway` class of the EuroSAT dataset

# %%
from PIL import Image

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %%
actual_img = [Image.open("./studies/Sagemaker_Study/SI/Highway/Highway/EuroSAT/Highway/Highway_{}.jpg".format(str(i))) for i in range(1,11)]
image_grid([x.resize((64,64)) for x in actual_img], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=320x128>

# %% [markdown]
# Let's view the `Forest` and `Industrial` classes:

# %%
actual_img = [Image.open("./studies/Sagemaker_Study/SI/Highway/Forest/EuroSAT/Forest/Forest_{}.jpg".format(str(i))) for i in range(1,11)]
image_grid([x.resize((64,64)) for x in actual_img], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=320x128>

# %%
actual_img = [Image.open("./studies/Sagemaker_Study/SI/Highway/Industrial/EuroSAT/Industrial/Industrial_{}.jpg".format(str(i))) for i in range(1,11)]
image_grid([x.resize((64,64)) for x in actual_img], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=320x128>

# %%
import shutil, os
forest_files = os.listdir("./studies/Sagemaker_Study/SI/Highway/Forest/EuroSAT/Forest")
industrial_files = os.listdir("./studies/Sagemaker_Study/SI/Highway/Industrial/EuroSAT/Industrial")

# %%
# !mkdir -p "./studies/Sagemaker_Study/SI/Highway/class"

# %%
for filename in forest_files:
    shutil.copyfile(
        os.path.join("./studies/Sagemaker_Study/SI/Highway/Forest/EuroSAT/Forest",filename),
        os.path.join("./studies/Sagemaker_Study/SI/Highway/class",filename)
    )
for filename in industrial_files:
    shutil.copyfile(
        os.path.join("./studies/Sagemaker_Study/SI/Highway/Industrial/EuroSAT/Industrial",filename),
        os.path.join("./studies/Sagemaker_Study/SI/Highway/class",filename)
    )

# %% [markdown]
# ## Base model Stable Diffusion generation
# Let's use Stable Diffusion (1.5) directly to generate satellite images of the `Highway` class.

# %%
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
import torch

pipe = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.to("cuda")
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading (…)_checker/config.json: 0.00B [00:00, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt: 0.00B [00:00, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json: 0.00B [00:00, ?B/s]
# Downloading (…)e6a/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)8e6a/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.18.0.dev0",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "DPMSolverMultistepScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
img_list = pipe(["Sentinel 2 satellite image of a highway"]*10, num_inference_steps=10).images
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
image_grid([x.resize((128,128)) for x in img_list], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=640x256>

# %%
import gc
from numba import cuda
del(pipe)
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Actual highway class images

# %%
actual_img = [Image.open("./studies/Sagemaker_Study/SI/Highway/Highway/EuroSAT/Highway/Highway_{}.jpg".format(str(i))) for i in range(1,11)]
image_grid([x.resize((64,64)) for x in actual_img], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=320x128>

# %% [markdown]
# We see that in terms of color and style there is a significant difference between Stable Diffusion direct generated images and the actual EuroSAT dataset images

# %% [markdown]
# ## Fine-tune Stable Diffusion with LORA and DreamBooth
# We want to fine-tune our text-to-image model to learn how to generate the right type of satellite images. To do so, we utilize two recent innovations, Dreambooth and LoRA. Dreambooth is a new method to allow models to learn to generate images that fit the distinct characteristics of the `instance` relative to the larger `class`. Low rank adapters (LoRA) allows for fast model training by drastically reducing the number of training parameters. We utilize the scripts found [here](https://github.com/huggingface/diffusers/blob/main/examples/dreambooth/README.md).

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora.py
# Out:
# --2023-06-23 05:25:28--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58646 (57K) [text/plain]
# Saving to: ‘train_dreambooth_lora.py.1’
#
# 100%[======================================>] 58,646      --.-K/s   in 0.002s
#
# 2023-06-23 05:25:28 (23.9 MB/s) - ‘train_dreambooth_lora.py.1’ saved [58646/58646]

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 24.7 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision) (1.22.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision) (2.29.0)
# Requirement already satisfied: torch==2.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (67.7.2)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.40.0)
# Requirement already satisfied: cmake in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.4)
# Requirement already satisfied: lit in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.15.2

# %%
# !accelerate launch train_dreambooth_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5"  \
  --instance_data_dir="./studies/Sagemaker_Study/SI/Highway/Highway/EuroSAT/Highway" \
  --output_dir=trained_model \
  --instance_prompt="Sentinel 2 satellite image of sks" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --checkpointing_steps=100 \
  --learning_rate=1e-4 \
  --report_to="tensorboard" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --with_prior_preservation \
  --class_data_dir="./studies/Sagemaker_Study/SI/Highway/class" \
  --class_prompt="Sentinel 2 satellite image" \
  --max_train_steps=1000 \
  --seed="0" \
  --mixed_precision="fp16"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 06/23/2023 05:30:50 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'thresholding', 'variance_type', 'dynamic_thresholding_ratio', 'clip_sample_range', 'prediction_type', 'sample_max_value'} was not found in config. Values will be initialized to default values.
# {'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'use_linear_projection', 'timestep_post_act', 'upcast_attention', 'addition_embed_type_num_heads', 'num_class_embeds', 'mid_block_type', 'resnet_out_scale_factor', 'dual_cross_attention', 'class_embed_type', 'time_embedding_dim', 'addition_embed_type', 'encoder_hid_dim', 'encoder_hid_dim_type', 'time_cond_proj_dim', 'conv_out_kernel', 'conv_in_kernel', 'mid_block_only_cross_attention', 'cross_attention_norm', 'time_embedding_act_fn', 'num_attention_heads', 'only_cross_attention', 'resnet_time_scale_shift', 'projection_class_embeddings_input_dim', 'resnet_skip_time_act', 'time_embedding_type', 'class_embeddings_concat'} was not found in config. Values will be initialized to default values.
# 06/23/2023 05:31:09 - INFO - __main__ - ***** Running training *****
# 06/23/2023 05:31:09 - INFO - __main__ -   Num examples = 2500
# 06/23/2023 05:31:09 - INFO - __main__ -   Num batches each epoch = 2500
# 06/23/2023 05:31:09 - INFO - __main__ -   Num Epochs = 1
# 06/23/2023 05:31:09 - INFO - __main__ -   Instantaneous batch size per device = 1
# 06/23/2023 05:31:09 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 06/23/2023 05:31:09 - INFO - __main__ -   Gradient Accumulation steps = 1
# 06/23/2023 05:31:09 - INFO - __main__ -   Total optimization steps = 1000
# Steps:  10%|▉        | 100/1000 [01:30<12:48,  1.17it/s, loss=0.0443, lr=0.0001]06/23/2023 05:32:40 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-100
# Model weights saved in trained_model/checkpoint-100/pytorch_lora_weights.bin
# 06/23/2023 05:32:40 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-100/optimizer.bin
# 06/23/2023 05:32:40 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-100/scheduler.bin
# 06/23/2023 05:32:40 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-100/scaler.pt
# 06/23/2023 05:32:40 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-100/random_states_0.pkl
# 06/23/2023 05:32:40 - INFO - __main__ - Saved state to trained_model/checkpoint-100
# Steps:  20%|█▊       | 200/1000 [02:58<11:30,  1.16it/s, loss=0.0131, lr=0.0001]06/23/2023 05:34:08 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-200
# Model weights saved in trained_model/checkpoint-200/pytorch_lora_weights.bin
# 06/23/2023 05:34:08 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-200/optimizer.bin
# 06/23/2023 05:34:08 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-200/scheduler.bin
# 06/23/2023 05:34:08 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-200/scaler.pt
# 06/23/2023 05:34:08 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-200/random_states_0.pkl
# 06/23/2023 05:34:08 - INFO - __main__ - Saved state to trained_model/checkpoint-200
# Steps:  30%|██▋      | 300/1000 [04:28<10:09,  1.15it/s, loss=0.0076, lr=0.0001]06/23/2023 05:35:38 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-300
# Model weights saved in trained_model/checkpoint-300/pytorch_lora_weights.bin
# 06/23/2023 05:35:38 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-300/optimizer.bin
# 06/23/2023 05:35:38 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-300/scheduler.bin
# 06/23/2023 05:35:38 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-300/scaler.pt
# 06/23/2023 05:35:38 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-300/random_states_0.pkl
# 06/23/2023 05:35:38 - INFO - __main__ - Saved state to trained_model/checkpoint-300
# Steps:  40%|████      | 400/1000 [05:56<08:13,  1.21it/s, loss=0.278, lr=0.0001]06/23/2023 05:37:06 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-400
# Model weights saved in trained_model/checkpoint-400/pytorch_lora_weights.bin
# 06/23/2023 05:37:06 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-400/optimizer.bin
# 06/23/2023 05:37:06 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-400/scheduler.bin
# 06/23/2023 05:37:06 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-400/scaler.pt
# 06/23/2023 05:37:06 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-400/random_states_0.pkl
# 06/23/2023 05:37:06 - INFO - __main__ - Saved state to trained_model/checkpoint-400
# Steps:  50%|█████     | 500/1000 [07:19<06:42,  1.24it/s, loss=0.064, lr=0.0001]06/23/2023 05:38:29 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-500
# Model weights saved in trained_model/checkpoint-500/pytorch_lora_weights.bin
# 06/23/2023 05:38:29 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-500/optimizer.bin
# 06/23/2023 05:38:29 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-500/scheduler.bin
# 06/23/2023 05:38:29 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-500/scaler.pt
# 06/23/2023 05:38:29 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-500/random_states_0.pkl
# 06/23/2023 05:38:29 - INFO - __main__ - Saved state to trained_model/checkpoint-500
# Steps:  60%|██████    | 600/1000 [08:42<05:28,  1.22it/s, loss=0.027, lr=0.0001]06/23/2023 05:39:52 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-600
# Model weights saved in trained_model/checkpoint-600/pytorch_lora_weights.bin
# 06/23/2023 05:39:52 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-600/optimizer.bin
# 06/23/2023 05:39:52 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-600/scheduler.bin
# 06/23/2023 05:39:52 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-600/scaler.pt
# 06/23/2023 05:39:52 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-600/random_states_0.pkl
# 06/23/2023 05:39:52 - INFO - __main__ - Saved state to trained_model/checkpoint-600
# Steps:  70%|███████   | 700/1000 [10:06<04:17,  1.16it/s, loss=0.258, lr=0.0001]06/23/2023 05:41:16 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-700
# Model weights saved in trained_model/checkpoint-700/pytorch_lora_weights.bin
# 06/23/2023 05:41:16 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-700/optimizer.bin
# 06/23/2023 05:41:16 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-700/scheduler.bin
# 06/23/2023 05:41:16 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-700/scaler.pt
# 06/23/2023 05:41:16 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-700/random_states_0.pkl
# 06/23/2023 05:41:16 - INFO - __main__ - Saved state to trained_model/checkpoint-700
# Steps:  80%|████████  | 800/1000 [11:31<02:42,  1.23it/s, loss=0.352, lr=0.0001]06/23/2023 05:42:41 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-800
# Model weights saved in trained_model/checkpoint-800/pytorch_lora_weights.bin
# 06/23/2023 05:42:41 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-800/optimizer.bin
# 06/23/2023 05:42:41 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-800/scheduler.bin
# 06/23/2023 05:42:41 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-800/scaler.pt
# 06/23/2023 05:42:41 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-800/random_states_0.pkl
# 06/23/2023 05:42:41 - INFO - __main__ - Saved state to trained_model/checkpoint-800
# Steps:  90%|████████ | 900/1000 [12:53<01:20,  1.25it/s, loss=0.0111, lr=0.0001]06/23/2023 05:44:03 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-900
# Model weights saved in trained_model/checkpoint-900/pytorch_lora_weights.bin
# 06/23/2023 05:44:03 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-900/optimizer.bin
# 06/23/2023 05:44:03 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-900/scheduler.bin
# 06/23/2023 05:44:03 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-900/scaler.pt
# 06/23/2023 05:44:03 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-900/random_states_0.pkl
# 06/23/2023 05:44:03 - INFO - __main__ - Saved state to trained_model/checkpoint-900
# Steps: 100%|████████| 1000/1000 [14:16<00:00,  1.22it/s, loss=0.0261, lr=0.0001]06/23/2023 05:45:26 - INFO - accelerate.accelerator - Saving current state to trained_model/checkpoint-1000
# Model weights saved in trained_model/checkpoint-1000/pytorch_lora_weights.bin
# 06/23/2023 05:45:26 - INFO - accelerate.checkpointing - Optimizer state saved in trained_model/checkpoint-1000/optimizer.bin
# 06/23/2023 05:45:26 - INFO - accelerate.checkpointing - Scheduler state saved in trained_model/checkpoint-1000/scheduler.bin
# 06/23/2023 05:45:26 - INFO - accelerate.checkpointing - Gradient scaler state saved in trained_model/checkpoint-1000/scaler.pt
# 06/23/2023 05:45:26 - INFO - accelerate.checkpointing - Random states saved in trained_model/checkpoint-1000/random_states_0.pkl
# 06/23/2023 05:45:26 - INFO - __main__ - Saved state to trained_model/checkpoint-1000
# Steps: 100%|████████| 1000/1000 [14:16<00:00,  1.22it/s, loss=0.0225, lr=0.0001]Model weights saved in trained_model/pytorch_lora_weights.bin
# {'requires_safety_checker'} was not found in config. Values will be initialized to default values.
# {'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'use_linear_projection', 'timestep_post_act', 'upcast_attention', 'addition_embed_type_num_heads', 'num_class_embeds', 'mid_block_type', 'resnet_out_scale_factor', 'dual_cross_attention', 'class_embed_type', 'time_embedding_dim', 'addition_embed_type', 'encoder_hid_dim', 'encoder_hid_dim_type', 'time_cond_proj_dim', 'conv_out_kernel', 'conv_in_kernel', 'mid_block_only_cross_attention', 'cross_attention_norm', 'time_embedding_act_fn', 'num_attention_heads', 'only_cross_attention', 'resnet_time_scale_shift', 'projection_class_embeddings_input_dim', 'resnet_skip_time_act', 'time_embedding_type', 'class_embeddings_concat'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# {'solver_order', 'solver_type', 'algorithm_type', 'lambda_min_clipped', 'thresholding', 'dynamic_thresholding_ratio', 'variance_type', 'lower_order_final', 'use_karras_sigmas', 'sample_max_value'} was not found in config. Values will be initialized to default values.
# Loading unet.
# Steps: 100%|████████| 1000/1000 [14:21<00:00,  1.16it/s, loss=0.0225, lr=0.0001]

# %% [markdown]
# ## Visualizing results
# Now that the model is trained, let's compare:
# 1. Stable Diffusion generated images without fine-tuning
# 2. Stable Diffusion generated images with LoRA and Dreambooth fine-tuning
# 3. Original EuroSAT images

# %%
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
import torch

# %%
pipe = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.to("cuda")
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.18.0.dev0",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "DPMSolverMultistepScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
from PIL import Image

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %%
img_list = pipe(["Sentinel 2 satellite image of a highway"]*10, num_inference_steps=25).images
image_grid([x.resize((256,256)) for x in img_list], 2,5)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1280x512>

# %%
pipe.unet.load_attn_procs("./trained_model/checkpoint-800")

# %%
img_list = pipe(["Sentinel 2 satellite image of sks"]*10, num_inference_steps=25).images
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
image_grid([x.resize((256,256)) for x in img_list], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x512>

# %%
from PIL.ImageOps import exif_transpose
actual_img = [exif_transpose(Image.open("./studies/Sagemaker_Study/SI/Highway/Highway/EuroSAT/Highway/Highway_{}.jpg".format(str(i)))) for i in range(1,11)]
image_grid([x.resize((64,64)) for x in actual_img], 2,5)
# Out:
# <PIL.Image.Image image mode=RGB size=320x128>

# %% [markdown]
# The generated images look much more realistic to before and we now have a lot more data to do whatever we wish with!
